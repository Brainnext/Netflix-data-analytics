# %% [markdown]
# <a href="https://colab.research.google.com/github/Brainnext/Netflix-data-analytics/blob/main/Data_Analytics_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IFT 502 ASSIGNMENT - Data Analytics
# ## DATA ACQUISITION AND DATA CLENSING/CLEANING
#
# **LECTURER-IN-CHARGE: PROF. O.A. DARAMOLA**

# %% [markdown]
# ### Importing all the libraries needed for the data acquisition and cleansing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sweetviz as sv

# %% [markdown]
# ### Installing sweetviz for visualization of data cleaning (If there is any duplicates, missing values, outliers etc)

# %%
pip install sweetviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 100.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Importing the Netflix dataset

# %%
Netflix_data = pd.read_csv("https://raw.githubusercontent.com/Brainnext/Netflix-data-analytics/main/Netflix%20Userbase.csv")
print (Netflix_data)
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %% [markdown]
# ### Displaying the dataset in a tabular form to show the fields and records

# %%
display(Netflix_data)
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %% [markdown]
# ### There are 2500 fields of data and 10 records of data variation of the Netflix dataset. (User ID, Subscription Type, Monthly Revenue, Joined data, Last Payment, Country, Age, Gender, Device, Plan Duration)

# %%
display(Netflix_data)
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
autoEDA = sv.analyze(Netflix_data)
autoEDA.show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# # QUESTION ONE: HOW WAS THE DATA ACQUIRED?
#
# ### The data was acquired on kaggle, it was then uploaded to Github and the raw file is then linked to this jupyter so we can work on the data.

# %% [markdown]
# # QUESTION TWO: DATA CLEANING/CLEANSING
#
# ### There are no duplicates in the data, no missing values, there are no outliers. The data is perfect!
# ### This observation was made with the Sweetviz library as shown above
